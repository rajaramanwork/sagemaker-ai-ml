# %%
# ************** Creating a custom training job in SageMaker**************************

# %%
# We use the Estimator from the SageMaker Python SDK
from sagemaker.sklearn.estimator import SKLearn
from sagemaker import get_execution_role
FRAMEWORK_VERSION = "0.23-1"

trainpath = "s3://my-ml-databucket/sagemaker/sklearncontainer/dry-bean-train.csv"
testpath = "s3://my-ml-databucket/sagemaker/sklearncontainer/dry-bean-test.csv"
sklearn_estimator = SKLearn(
   entry_point="script.py",
   role=get_execution_role(),
   instance_count=1,
   instance_type="ml.c5.xlarge",
   framework_version=FRAMEWORK_VERSION,
   base_job_name="rf-scikit",
   hyperparameters={
       "n-estimators": 100,
       "min-samples-leaf": 3,
   },
)
# Launch training job, with asynchronous call
sklearn_estimator.fit({"train": trainpath, "test": testpath}, wait=True)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# INFO:sagemaker:Creating training-job with name: rf-scikit-2025-06-15-02-08-34-023
# 2025-06-15 02:08:36 Starting - Starting the training job...
# 2025-06-15 02:09:09 Downloading - Downloading input data...
# 2025-06-15 02:09:25 Downloading - Downloading the training image...
# 2025-06-15 02:10:06 Training - Training image download completed. Training in progress.
# 2025-06-15 02:10:06 Uploading - Uploading generated training model2025-06-15 02:10:01,107 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2025-06-15 02:10:01,110 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2025-06-15 02:10:01,145 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2025-06-15 02:10:01,299 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2025-06-15 02:10:01,309 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2025-06-15 02:10:01,320 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2025-06-15 02:10:01,327 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "min-samples-leaf": 3,
#         "n-estimators": 100
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "rf-scikit-2025-06-15-02-08-34-023",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-586794478771/rf-scikit-2025-06-15-02-08-34-023/source/sourcedir.tar.gz",
#     "module_name": "script",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.c5.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.c5.xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0",
#         "topology": null
#     },
#     "user_entry_point": "script.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"min-samples-leaf":3,"n-estimators":100}
# SM_USER_ENTRY_POINT=script.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.xlarge"}],"network_interface_name":"eth0","topology":null}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=script
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-586794478771/rf-scikit-2025-06-15-02-08-34-023/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"min-samples-leaf":3,"n-estimators":100},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"rf-scikit-2025-06-15-02-08-34-023","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-586794478771/rf-scikit-2025-06-15-02-08-34-023/source/sourcedir.tar.gz","module_name":"script","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.xlarge"}],"network_interface_name":"eth0","topology":null},"user_entry_point":"script.py"}
# SM_USER_ARGS=["--min-samples-leaf","3","--n-estimators","100"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MIN-SAMPLES-LEAF=3
# SM_HP_N-ESTIMATORS=100
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
# Invoking script with the following command:
# /miniconda3/bin/python script.py --min-samples-leaf 3 --n-estimators 100
# extracting arguments
# ----env variables---
# reading data
# building training and testing datasets
# training model
# script.py:51: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# validating model
# Train balanced accuracy: 1.000
# Test balanced accuracy: 0.997
# model persisted at /opt/ml/model/model.joblib
# 2025-06-15 02:10:03,204 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2025-06-15 02:10:19 Completed - Training job completed
# Training seconds: 70
# Billable seconds: 70
